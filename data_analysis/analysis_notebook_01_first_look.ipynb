# %% [markdown]
# # First Look
# ### Objective:
# - Have the FAANG stocks done well (if not, better) during 2020?
#
# #### Steps:
# - What are the FAANG stocks?
# - Graphing the past 5 years stock performance of the FAANG stocks
# - Analyzing and looking for next steps

# %%
import os

os.chdir("/Commjhub/jupyterhub/comm318_fall2019/daniellegin/comm318_F20/comm318_F20_Final_Project")

# %%
# %run data_analysis/get_functions.ipynb

# %%
stock_list = get_FAANG_stocks()

for stock in stock_list:
    print(stock.ticker)
# Out:
# AMZN
# GOOG
# NFLX
# AAPL
# FB

# %% [markdown]
# # Graphing the historical data.
# Closing price of the FAANG stocks within the past 5 years.

# %%
for stock in stock_list:
    graph_x_list_and_y_list(stock.history_df.index, stock.history_df["Close"], stock.company_name)

plt.xlabel("Date")
plt.ylabel("Price (dollars)")
plt.title("FAANG Historical Closing Prices")
plt.legend(loc="upper left")
plt.grid()

plt.show()

# %% [markdown]
# # Insights and Anaylsis: FAANG Stocks Performance
# The graph above shows the closing prices of the FAANG stocks in the _past 5 years_. In this simple analysis, we will assume that stock price indicates the companies' overall performance. The more expensive the stock price, the better the company is performing.
#
# In the past 5 years (2016-2020), we can see an overall growth in the technology sector. However, it is very interesting to see that in the year 2020, some technology companies seem to have grown even more. Specifically, Amazon and Google (Alphabet) have grown greatly-- aside from the dips in March 2020 and September 2020. From this graph alone, it seems as if Apple and Facebook did not have much growth. However, this could be due to Amazon and Google's huge growth. We will look more into the stocks individually.
#
# In the `analysis_notebook_01_trading_analysis.ipynb` notebook, we will have a deeper look into the performance of each individual FAANG stock.
